# %%
import jax
import jax.numpy as jnp
import jax.scipy as jsp
import jax.random as jr
import jax.scipy.special as jss
import healpy as hp
import astropy as ap
from astropy.coordinates import SkyCoord
from dustmaps.edenhofer2023 import Edenhofer2023Query
import astropy.units as u
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import matplotlib.pyplot as plt

from pathlib import Path

results_dir = Path("/home/dtfrake/hmc-dust/sherlock_results_2")
stem = "overall_data_Gaia_XP_fitting_actual_data_40345618"

chains = [
    jnp.asarray(np.load(results_dir / f"{stem}_chain{i}.npy"))
    for i in range(5)
]

overall_data_arr_combined = jnp.concatenate(chains, axis=0)
print(overall_data_arr_combined.shape)  # expect (1000, n_params)

np.save(results_dir / f"{stem}_combined.npy", np.asarray(overall_data_arr_combined))
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# (5000, 7660)
